# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/home/anm/rera_telangana/reratelangna.csv')

# %%
df.head()
# Out:
#   Unnamed: 0                     0                 1           2           3  \
# 0     TS0001    SKV S ANANDA VILAS       New Project         NaN  17/04/2024
# 1     TS0002        MY HOME KRISHE  On-Going Project  09/02/2018  08/02/2024
# 2     TS0003     RAJAPUSHPA ETERNA       New Project         NaN  31/12/2021
# 3     TS0004  SMR VINAY METRO MALL  On-Going Project         NaN  09/02/2023
# 4     TS0005   MYSCAPE-ISLE OF SKY  On-Going Project         NaN  30/06/2021
#
#              4    5    6            7         8  ...        15         16  \
# 0  Residential   No  Yes            0  10-2-327  ...    144.28  Telangana
# 1  Residential   No  Yes  38,39,40,41       NaN  ...  18101.00  Telangana
# 2  Residential  Yes  Yes        337/P       NaN  ...   7800.00  Telangana
# 3   Commercial   No  Yes      50 & 61       NaN  ...   1386.67  Telangana
# 4  Residential   No  Yes         323P       NaN  ...   2013.76  Telangana
#
# ...

# %%
l=df.values.tolist()

# %%
l
# Out:
# [['TS0001',
#   'SKV S ANANDA VILAS',
#   'New Project',
#   nan,
#   '17/04/2024',
#   'Residential',
#   'No',
#   'Yes',
#   '0',
#   '10-2-327',
#   526.74,
#   58.51,
#   1.0,
#   1.0,
#   1.0,
#   1313.55,
#   144.28,
#   'Telangana',
#   'Hyderabad',
#   'Maredpally',
#   nan,
#   'ROAD NO 8',
#   'SECUNDERABAD COURT',
#   500026,
#   nan,
#   '1/18B/06558/2018'],
#  ['TS0002',
#   'MY HOME KRISHE',
#   'On-Going Project',
#   '09/02/2018',
#   '08/02/2024',
#   'Residential',
#   'No',
#   'Yes',
#   '38,39,40,41',
#   nan,
#   27923.0,
#   790.0,
#   27133.0,
#   3.0,
#   3.0,
#   118774079.0,
#   18101.0,
#   'Telangana',
#   'Ranga Reddy',
#   'Serilingampally',
#   nan,
#   'Hitech City Road',
#   'Madhapur',
#   500046,
#   nan,
#   nan],
#  ['TS0003',
#   'RAJAPUSHPA ETERNA',
#   'New Project',
#   nan,
#   '31/12/2021',
#   'Residential',
#   'Yes',
#   'Yes',
#   '337/P',
#   nan,
#   20871.66,
#   2104.34,
#   18767.32,
#   4.0,
#   4.0,
#   70158.07,
#   7800.0,
# ...

# %%
#maha

df_final=pd.DataFrame(l,columns=['Project ID','Project_name','Project_Status','Pro_date_completion',
                                                                           'Project_type','Total_building_count','Area','Street_name','Locality',
                                                                           'State','Division','District','Taluka','Village','Pincode','Sanctioned_building_count',
                                                                           'Built_up_Area_as_per_Proposed_FSI','Built_up_Area_as_per_Approved_FSI'])

# %%
#telangana
df_final=pd.DataFrame(l,columns =['Project_ID','Project_name','Project_status','Approval_date','Proposed_date_completion','Project_type',
                        'Letigation','Promoter','Sy_no','Plot_house_no','Total_area','Area_Afected_road_widen','Net_area','Total_building_unit',
                        'Proposed_building_unit','Approved_build_up_area', 'Mortgage_area','State','District','Mandal','Village','Street','Locality',
                           'Pincode','Authority_name','Plan_approval_no'])

# %%
df_final.head()
# Out:
#   Project_ID          Project_name    Project_status Approval_date  \
# 0     TS0001    SKV S ANANDA VILAS       New Project           NaN
# 1     TS0002        MY HOME KRISHE  On-Going Project    09/02/2018
# 2     TS0003     RAJAPUSHPA ETERNA       New Project           NaN
# 3     TS0004  SMR VINAY METRO MALL  On-Going Project           NaN
# 4     TS0005   MYSCAPE-ISLE OF SKY  On-Going Project           NaN
#
#   Proposed_date_completion Project_type Letigation Promoter        Sy_no  \
# 0               17/04/2024  Residential         No      Yes            0
# 1               08/02/2024  Residential         No      Yes  38,39,40,41
# 2               31/12/2021  Residential        Yes      Yes        337/P
# 3               09/02/2023   Commercial         No      Yes      50 & 61
# 4               30/06/2021  Residential         No      Yes         323P
#
#   Plot_house_no  ...  Mortgage_area      State     District           Mandal  \
# ...

# %%
df_final.to_csv('/home/anm/rera_telangana/rera_telangna_final.csv')
